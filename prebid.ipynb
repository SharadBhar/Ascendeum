# %%
import pandas as pd

# %%
df=pd.read_csv('analysis_id(in).csv')

# %%
df
# Out:
#       Unnamed: 0            date_hour     client device_type  \
# 0              0  2021-04-11T01:00:00  asc126828     Desktop
# 1              1  2021-04-11T01:00:00  asc126828     Desktop
# 2              2  2021-04-11T01:00:00  asc126828     Desktop
# 3              3  2021-04-11T01:00:00  asc126828     Desktop
# 4              4  2021-04-11T01:00:00  asc126828     Desktop
# ...          ...                  ...        ...         ...
# 4995        4995  2021-04-11T01:00:00  asc126828     Desktop
# 4996        4996  2021-04-11T01:00:00  asc126828     Desktop
# 4997        4997  2021-04-11T01:00:00  asc126828     Desktop
# 4998        4998  2021-04-11T01:00:00  asc126828     Desktop
# 4999        4999  2021-04-11T01:00:00  asc126828     Desktop
#
#              time_zone  os_name        browser_name  \
# 0      America/Chicago    Linux  Chrome-85.04183133
# 1      America/Chicago    Linux  Chrome-85.04183133
# 2      America/Chicago    Linux  Chrome-85.04183133
# ...

# %%
# Question 1: The above data is data for prebid auctions. 
# There are bidders who receive requests for placing ads, they respond to these requests with a bid and the highest bid wins the auction.
# Analyse the dataset to answer which bidder has the highest win rate (wins / total_bid).

df.columns
# Out:
# Index(['Unnamed: 0', 'date_hour', 'client', 'device_type', 'time_zone',
#        'os_name', 'browser_name', 'ad_unit', 'size', 'bidder', 'bid_range',
#        'media_type', 'request_count', 'response_count', 'prebid_win_count',
#        'win_count', 'sum_bid', 'sum_time_to_respond', 'median', 'min_bid',
#        'max_bid', 'avg_bid', 'sum_2nd_highest_bid', 'sum_prebid_winning_bid',
#        'sum_winning_bid', 'sum_nobid', 'sum_timeout'],
#       dtype='str')

# %%
df['bidder'].nunique()
# Out:
# 18

# %%
# prebid win count vs win count- need to look about it
# media - type- need to see
df['win_count']=df['win_count'].fillna(0)
df['prebid_win_count']=df['prebid_win_count'].fillna(0)
# win rate calculation
df['win_rate']=df['win_count']/df['response_count']
df['prebid_win_rate']=df['prebid_win_count']/df['response_count']
bidder_stats=df.groupby('bidder').agg({
    'win_count':'sum',
    'prebid_win_count':'sum',
    'response_count':'sum'
})
bidder_stats['overall_win_rate_pct']=(bidder_stats['win_count']/bidder_stats['response_count'])*100
bidder_stats['prebin_win_rate_pct']=(bidder_stats['prebid_win_count']/bidder_stats['response_count'])*100

# %%
bidder_stats.sort_values(by='overall_win_rate_pct',ascending=False).head()
# Out:
#               win_count  prebid_win_count  response_count  \
# bidder
# undertone          16.0              52.0             104
# emx_digital        20.0              56.0             393
# sharethrough       10.0             104.0             332
# rhythmone          18.0             160.0             655
# pulsepoint          5.0              71.0             191
#
#               overall_win_rate_pct  prebin_win_rate_pct
# bidder
# undertone                15.384615            50.000000
# emx_digital               5.089059            14.249364
# sharethrough              3.012048            31.325301
# rhythmone                 2.748092            24.427481
# pulsepoint                2.617801            37.172775
